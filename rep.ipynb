# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanZinchenko3214/dap-2024/blob/main/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Отчет по лабораторной работе №1. Подготовка среды для анализа данных
#
# ## **В ходе лабораторной работы:**
#
# 1.   Создал учетную запись в сервисе GitHub
# 2.   Выполнил [форк репозитория](https://docs.google.com/drawings/d/1x_mORLC70wcYVTtDm0ZImyBa77k5D1TGhszrd71r3gA/edit?usp=sharing)
# 3.   Создал [учетную запись](https://docs.google.com/drawings/d/1CcvNmMbU_FbVPVsYnRwMGM6CSHRGIsedYRWLsuEBnCQ/edit?usp=sharing) в Google Colab
# 4.   Настроил [интеграцию](https://docs.google.com/drawings/d/1bJRRSDATtBKY9EgX9C9MCqmH6dPA0QXjXelxLViODAI/edit?usp=sharing) Google Colab и GitHub
# 5.   Создал в Google Colab отчет о выполненой работе в виде файла rep.ipynb. Использовал Markdown разметку (заголовки, списки, форматированный текст, ссылки)
# 6.   Сохранил отчет в репозиторий github в директории *./les01*
# 6.   Создал pull request в репозиторий.
